# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import pandas as pd

# %% [markdown]
# Load in data and bullshit

# %%
df = pd.read_csv("IMDBDataset.csv")
corpus = df['review']

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '00000000000', ..., 'żmijewski', 'יגאל', 'כרמון'],
#       shape=(101895,), dtype=object)

# %%
row = X[1]
feature_names = vectorizer.get_feature_names_out()
nonzero_idx = row.nonzero()[1]
for i in nonzero_idx:
    print(f"{feature_names[i]:15s} {row[0, i]:.4f}")

print(feature_names.index("watching"))
# Out:
# one             1.0000
# of              5.0000
# the             16.0000
# has             2.0000
# watching        1.0000
# you             1.0000
# are             2.0000
# is              3.0000
# with            3.0000
# br              6.0000
# about           1.0000
# and             7.0000
# scenes          1.0000
# which           1.0000
# not             2.0000
# to              2.0000
# use             1.0000
# it              3.0000
# on              1.0000
# all             2.0000
# home            1.0000
# but             2.0000
# got             1.0000
# well            3.0000
# their           1.0000
# can             1.0000
# wonderful       1.0000
# little          2.0000
# production      2.0000
# filming         1.0000
# technique       1.0000
# very            2.0000
# unassuming      1.0000
# old             1.0000
# time            1.0000
# bbc             1.0000
# fashion         1.0000
# gives           1.0000
# comforting      1.0000
# sometimes       1.0000
# discomforting   1.0000
# sense           1.0000
# realism         2.0000
# entire          1.0000
# piece           2.0000
# actors          1.0000
# extremely       1.0000
# chosen          1.0000
# michael         1.0000
# sheen           1.0000
# only            2.0000
# polari          1.0000
# he              1.0000
# voices          1.0000
# down            1.0000
# pat             1.0000
# too             1.0000
# truly           1.0000
# see             1.0000
# seamless        1.0000
# editing         1.0000
# guided          1.0000
# by              1.0000
# references      1.0000
# williams        1.0000
# diary           1.0000
# entries         1.0000
# worth           1.0000
# terrificly      1.0000
# written         1.0000
# performed       1.0000
# masterful       1.0000
# great           1.0000
# master          1.0000
# comedy          1.0000
# his             1.0000
# life            1.0000
# really          1.0000
# comes           1.0000
# things          1.0000
# fantasy         1.0000
# guard           1.0000
# rather          1.0000
# than            1.0000
# traditional     1.0000
# dream           1.0000
# techniques      1.0000
# remains         1.0000
# solid           1.0000
# then            1.0000
# disappears      1.0000
# plays           1.0000
# our             2.0000
# knowledge       1.0000
# senses          1.0000
# particularly    2.0000
# concerning      1.0000
# orton           1.0000
# halliwell       2.0000
# sets            1.0000
# flat            1.0000
# murals          1.0000
# decorating      1.0000
# every           1.0000
# surface         1.0000
# terribly        1.0000
# done            1.0000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       3 nonzero_idx = row.nonzero()[1]
#       4 for i in nonzero_idx:
#       5     print(f"{feature_names[i]:15s} {row[0, i]:.4f}")
#       6
# ----> 7 print(feature_names.index("watching"))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
import matplotlib.pyplot as plt

plt.hist(X[:, 234].toarray().flatten())
# Out:
# (array([4.9057e+04, 8.6700e+02, 6.7000e+01, 0.0000e+00, 5.0000e+00,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([0. , 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

train, test = train_test_split(df)

X_train = vectorizer.fit_transform(train['review'])
y_train = train['sentiment']

X_test = vectorizer.transform(test['review'])
y_test = test['sentiment']



nb = MultinomialNB(alpha=1.0)
nb.fit(X_train, y_train)
preds = nb.predict(X_test)

accuracy_score(preds, y_test)
# Out:
# 0.84264
